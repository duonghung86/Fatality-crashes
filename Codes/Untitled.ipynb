# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('GS_weights_2.xlsx')

# %%
df
# Out:
#     Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0            0      78.845459     56.691740         1.940001        2.679838
# 1            1      33.708505      7.154475         0.589979        0.156707
# 2            2      41.760794     10.071626         0.614667        0.147462
# 3            3      32.708208      4.876565         0.658592        0.259408
# 4            4      30.809450      3.151769         0.465920        0.040943
# 5            5      29.670832      6.327154         0.653249        0.428754
# 6            6      33.215106      2.008437         0.444350        0.021471
# 7            7      32.136094      1.796547         0.446608        0.017987
# 8            8      60.856715      6.821659         0.475982        0.047974
# 9            9      38.124737      6.423394         0.449214        0.008336
# 10          10      37.198307      7.803869         0.467108        0.028412
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'mean_fit_time', 'std_fit_time', 'mean_score_time',
#        'std_score_time', 'param_batch_size', 'param_lr', 'param_nodes',
#        'params', 'split0_test_BA', 'split1_test_BA', 'split2_test_BA',
#        'split3_test_BA', 'split4_test_BA', 'mean_test_BA', 'std_test_BA',
#        'rank_test_BA', 'split0_test_AUC', 'split1_test_AUC', 'split2_test_AUC',
#        'split3_test_AUC', 'split4_test_AUC', 'mean_test_AUC', 'std_test_AUC',
#        'rank_test_AUC'],
#       dtype='object')

# %%
plt.scatter(df.param_batch_size,df.mean_test_BA)
plt.scatter(df.param_batch_size,df.mean_test_AUC)

# %%
plt.scatter(df.param_lr,df.mean_test_BA)
plt.scatter(df.param_lr,df.mean_test_AUC)

# %%
plt.scatter(df.param_nodes,df.mean_test_BA)
plt.scatter(df.param_nodes,df.mean_test_AUC)
