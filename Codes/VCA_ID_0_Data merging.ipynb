# %% [markdown]
# # Import dataset
# ---

# %%
# Import packages
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
from io import StringIO
from io import BytesIO
from zipfile import ZipFile
import urllib.request

# %% [markdown]
# ## Function to obtain data set from zip link

# %%
def zip2df(link):
    # Open the url link
    url = urllib.request.urlopen(link)
    
    # Open as zip file
    with ZipFile(BytesIO(url.read())) as my_zip_file:
        for contained_file in my_zip_file.namelist():
            fzip=my_zip_file.open(contained_file)
            print(contained_file)
            data=fzip.read()
    # Convert bytes object to string object
    s=str(data,'utf-8')
    data = StringIO(s) 
    # convert it to pandas DataFrame as normal csv file
    df=pd.read_csv(data)
    return df

# %% [markdown]
# ## Crash data

# %%
link_crash='https://github.com/duonghung86/Fatality-crashes/raw/master/Data/extract_2018_20191217230653_crash_20190601-20191130Texas.zip'
df_crash=zip2df(link_crash)
df_crash.tail()
# Out:
# extract_2018_20191217230653_crash_20190601-20191130Texas.csv
# C:\Anaconda\envs\tf\lib\site-packages\IPython\core\interactiveshell.py:3254: DtypeWarning: Columns (20,35,44,46,82,86,90,93,156,157) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
#         Crash_ID Crash_Fatal_Fl Cmv_Involv_Fl Schl_Bus_Fl Rr_Relat_Fl  \
# 324112  17460951              N             N           N           N
# 324113  17460958              N             N           N           N
# 324114  17460970              N             N           N           N
# 324115  17461030              N             N           N           N
# 324116  17461292              N             N           N           N
#
#        Medical_Advisory_Fl Amend_Supp_Fl Active_School_Zone_Fl  Crash_Date  \
# 324112                   N             N                     N  11/28/2019
# 324113                   N             N                     N  11/29/2019
# 324114                   N             N                     N  11/29/2019
# 324115                   N             N                     N  11/25/2019
# 324116                   N             N                     N  09/03/2019
#
#        Crash_Time  ... Nonincap_Injry_Cnt Poss_Injry_Cnt  Non_Injry_Cnt  \
# 324112   12:48 PM  ...                  0              0              1
# 324113   02:57 AM  ...                  0              0              1
# 324114   11:13 AM  ...                  0              0              1
# 324115   11:06 AM  ...                  0              1              1
# 324116   04:15 PM  ...                  0              0              2
#
#         Unkn_Injry_Cnt Tot_Injry_Cnt Death_Cnt  MPO_ID  Investigat_Service_ID  \
# 324112               0             0         0     NaN                    1.0
# 324113               0             0         0     NaN                    NaN
# 324114               0             0         0     NaN                  485.0
# 324115               0             1         0     NaN                   23.0
# 324116               0             0         0     NaN                    NaN
#
#         Investigat_DA_ID Investigator_Narrative
# 324112               8.0                    NaN
# 324113               NaN                    NaN
# 324114             321.0                    NaN
# 324115               NaN                    NaN
# 324116               NaN                    NaN
#
# [5 rows x 173 columns]

# %% [markdown]
# ## Person data

# %%
link_person='https://github.com/duonghung86/Fatality-crashes/raw/master/Data/extract_2018_20191217230653_primaryperson_20190601-20191130Texas.zip'
df_person=zip2df(link_person)
df_person.tail()
# Out:
# extract_2018_20191217230653_primaryperson_20190601-20191130Texas.csv
#         Crash_ID  Unit_Nbr  Prsn_Nbr  Prsn_Type_ID  Prsn_Occpnt_Pos_ID  \
# 597978  17460970         1         1             1                   1
# 597979  17461030         1         1             1                   1
# 597980  17461030         2         1             1                   1
# 597981  17461292         1         1             1                   1
# 597982  17461292         2         1             1                   1
#
#         Prsn_Name_Honorific Prsn_Last_Name Prsn_First_Name Prsn_Mid_Name  \
# 597978                  NaN         MASSEY         WILLIAM         DOYLE
# 597979                  NaN        MATTHYS           JASON        DONALD
# 597980                  NaN         BOWSER         SHERRYE           ANN
# 597981                  NaN           REED         HALEIGH        MACLAY
# 597982                  NaN         TURNER           LANCE       MATTHEW
#
#        Prsn_Name_Sfx  ...  Drvr_Lic_Cls_ID    Drvr_DOB  Drvr_Street_Nbr  \
# 597978           NaN  ...              1.0  12/02/1950              817
# 597979           NaN  ...              3.0  10/01/1975             1055
# 597980           NaN  ...              3.0  11/24/1962              206
# 597981           NaN  ...              3.0  11/26/2002              869
# 597982           NaN  ...              3.0  06/16/2003             8930
#
#         Drvr_Street_Pfx   Drvr_Street_Name  Drvr_Street_Sfx  Drvr_Apt_Nbr  \
# 597978                N               PARK              AVE           NaN
# 597979                W            FM 2625              NaN           NaN
# 597980                W           BROADWAY               ST           NaN
# 597981              NaN        PORTERVILLE               RD           NaN
# 597982                E  STATE HIGHWAY 103              NaN           NaN
#
#         Drvr_City_Name Drvr_State_ID  Drvr_Zip
# 597978     KARNES CITY          43.0     78118
# 597979        MARSHALL          43.0     75672
# 597980       JEFFERSON          43.0     75657
# 597981      HUNTINGTON          43.0       NaN
# 597982          LUFKIN          43.0       NaN
#
# [5 rows x 49 columns]

# %% [markdown]
# ## Unit data

# %%
link_unit='https://github.com/duonghung86/Fatality-crashes/raw/master/Data/extract_2018_20191217230653_unit_20190601-20191130Texas.zip'
df_unit=zip2df(link_unit)
df_unit.tail()
# Out:
# extract_2018_20191217230653_unit_20190601-20191130Texas.csv
# C:\Anaconda\envs\tf\lib\site-packages\IPython\core\interactiveshell.py:3254: DtypeWarning: Columns (57) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
#         Crash_ID  Unit_Nbr  Unit_Desc_ID Veh_Parked_Fl Veh_HNR_Fl  \
# 654537  17460970         1             1             N          N
# 654538  17461030         1             1             N          N
# 654539  17461030         2             1             N          N
# 654540  17461292         1             1             N          N
# 654541  17461292         2             1             N          N
#
#         Veh_Lic_State_ID Veh_Lic_Plate_Nbr                VIN  Veh_Mod_Year  \
# 654537              43.0           MDD3540  1FTEW1CPXKKD89353        2019.0
# 654538              43.0           MKH5765  1G2ZJ57B894263596        2009.0
# 654539              43.0           HDZ4147  5YFBU4EE8DP143573        2013.0
# 654540              43.0           FSG1989  2GNALBEK1C6316947        2012.0
# 654541              43.0           AU70090  2GCEK19T641183157        2004.0
#
#         Veh_Color_ID  ...  Tot_Injry_Cnt  Death_Cnt  Cmv_Disabling_Damage_Fl  \
# 654537          99.0  ...              0          0                      NaN
# 654538           9.0  ...              0          0                      NaN
# 654539           2.0  ...              1          0                      NaN
# 654540          18.0  ...              0          0                      NaN
# 654541          18.0  ...              0          0                      NaN
#
#        Cmv_Bus_Type_ID Trlr_GVWR Trlr_RGVW Trlr_Type_ID  \
# 654537             NaN       NaN       NaN          NaN
# 654538             NaN       NaN       NaN          NaN
# 654539             NaN       NaN       NaN          NaN
# 654540             NaN       NaN       NaN          NaN
# 654541             NaN       NaN       NaN          NaN
#
#        Trlr_Disabling_Dmag_ID Cmv_Intermodal_Container_Permit_Fl  \
# 654537                    NaN                                NaN
# 654538                    NaN                                NaN
# 654539                    NaN                                NaN
# 654540                    NaN                                NaN
# 654541                    NaN                                NaN
#
#         CMV_Actual_Gross_Weight
# 654537                      NaN
# 654538                      NaN
# 654539                      NaN
# 654540                      NaN
# 654541                      NaN
#
# [5 rows x 100 columns]

# %% [markdown]
# # Features filtering

# %% [markdown]
# ## Person data

# %%
df_person.shape
# Out:
# (597983, 49)

# %%
# Percentage of missing values for each feature
mvr=df_person.isna().sum()/len(df_person.Crash_ID)
valid_feat=mvr[mvr<0.2].index
print(len(valid_feat))
valid_feat
# Out:
# 36
# Index(['Crash_ID', 'Unit_Nbr', 'Prsn_Nbr', 'Prsn_Type_ID',
#        'Prsn_Occpnt_Pos_ID', 'Prsn_Last_Name', 'Prsn_First_Name',
#        'Prsn_Injry_Sev_ID', 'Prsn_Age', 'Prsn_Ethnicity_ID', 'Prsn_Gndr_ID',
#        'Prsn_Ejct_ID', 'Prsn_Rest_ID', 'Prsn_Airbag_ID', 'Prsn_Helmet_ID',
#        'Prsn_Sol_Fl', 'Prsn_Alc_Spec_Type_ID', 'Prsn_Drg_Spec_Type_ID',
#        'Prsn_Drg_Rslt_ID', 'Drvr_Drg_Cat_1_ID', 'Sus_Serious_Injry_Cnt',
#        'Nonincap_Injry_Cnt', 'Poss_Injry_Cnt', 'Non_Injry_Cnt',
#        'Unkn_Injry_Cnt', 'Tot_Injry_Cnt', 'Death_Cnt', 'Drvr_Lic_Type_ID',
#        'Drvr_Lic_State_ID', 'Drvr_Lic_Number', 'Drvr_Lic_Cls_ID', 'Drvr_DOB',
#        'Drvr_Street_Name', 'Drvr_City_Name', 'Drvr_State_ID', 'Drvr_Zip'],
#       dtype='object')

# %%
df_person=df_person[valid_feat].copy()
df_person.head()
# Out:
#    Crash_ID  Unit_Nbr  Prsn_Nbr  Prsn_Type_ID  Prsn_Occpnt_Pos_ID  \
# 0  15657177         1         1             1                   1
# 1  16473665         1         1             1                   1
# 2  16473665         2         1             1                   1
# 3  16871051         1         1             1                   1
# 4  16871051         3         1             1                   1
#
#   Prsn_Last_Name Prsn_First_Name  Prsn_Injry_Sev_ID  Prsn_Age  \
# 0          RAMOS           ISAAC                  0      16.0
# 1          ADAMS         CHARLES                  5      48.0
# 2        JOHNNIE          PAMELA                  2      58.0
# 3         MILLER          JACKIE                  5      68.0
# 4        FEDERLE           LINDA                  5      67.0
#
#    Prsn_Ethnicity_ID  ...  Death_Cnt  Drvr_Lic_Type_ID  Drvr_Lic_State_ID  \
# 0                2.0  ...          0               9.0               43.0
# 1                1.0  ...          0               9.0               43.0
# 2                1.0  ...          0               9.0               43.0
# 3                1.0  ...          0               9.0               43.0
# 4                1.0  ...          0               9.0               43.0
#
#    Drvr_Lic_Number  Drvr_Lic_Cls_ID    Drvr_DOB  Drvr_Street_Name  \
# 0         13174627              3.0         NaN             FM 56
# 1         14022783              7.0  07/07/1970          Cemetary
# 2         09872112              3.0  06/06/1961         McMillian
# 3         01225977              1.0  09/22/1950       6168 CR 988
# 4         09215492              3.0  09/27/1951   1261 ALTO VISTA
#
#    Drvr_City_Name  Drvr_State_ID  Drvr_Zip
# 0    GLEN ROSE TX           43.0     76043
# 1         Silsbee           43.0     77656
# 2      Kirbyville           43.0     75956
# 3   COLLIN COUNTY           43.0     75071
# 4        FAIRVIEW           43.0     75069
#
# [5 rows x 36 columns]

# %%
keeps=['Crash_ID', 'Unit_Nbr', 'Prsn_Nbr', 'Prsn_Type_ID',
       'Prsn_Occpnt_Pos_ID', 
       'Prsn_Injry_Sev_ID', 'Prsn_Age', 'Prsn_Ethnicity_ID', 'Prsn_Gndr_ID',
       'Prsn_Ejct_ID', 'Prsn_Rest_ID', 'Prsn_Airbag_ID', 'Prsn_Helmet_ID',
       'Prsn_Drg_Rslt_ID']
df_person=df_person[keeps].copy()
df_person.head()
# Out:
#    Crash_ID  Unit_Nbr  Prsn_Nbr  Prsn_Type_ID  Prsn_Occpnt_Pos_ID  \
# 0  15657177         1         1             1                   1
# 1  16473665         1         1             1                   1
# 2  16473665         2         1             1                   1
# 3  16871051         1         1             1                   1
# 4  16871051         3         1             1                   1
#
#    Prsn_Injry_Sev_ID  Prsn_Age  Prsn_Ethnicity_ID  Prsn_Gndr_ID  Prsn_Ejct_ID  \
# 0                  0      16.0                2.0             1             1
# 1                  5      48.0                1.0             1             1
# 2                  2      58.0                1.0             2             1
# 3                  5      68.0                1.0             1             1
# 4                  5      67.0                1.0             2             1
#
#    Prsn_Rest_ID  Prsn_Airbag_ID  Prsn_Helmet_ID  Prsn_Drg_Rslt_ID
# 0             1               8              97                97
# 1             1               2              97                97
# 2             1               3              97                 1
# 3             1               2              97                97
# 4             1               4              97                97

# %%
df_final=df_person.copy()

# %% [markdown]
# ## Crash data

# %%
df_crash.shape
# Out:
# (324117, 173)

# %%
# Percentage of missing values for each feature
mvr=df_crash.isna().sum()/len(df_crash.Crash_ID)
valid_feat=mvr[mvr<0.2].index
print(len(valid_feat))
valid_feat
# Out:
# 74
# Index(['Crash_ID', 'Crash_Fatal_Fl', 'Cmv_Involv_Fl', 'Schl_Bus_Fl',
#        'Rr_Relat_Fl', 'Medical_Advisory_Fl', 'Amend_Supp_Fl',
#        'Active_School_Zone_Fl', 'Crash_Date', 'Crash_Time', 'Case_ID',
#        'Rpt_CRIS_Cnty_ID', 'Rpt_City_ID', 'Rpt_Outside_City_Limit_Fl',
#        'Thousand_Damage_Fl', 'Rpt_Rdwy_Sys_ID', 'Rpt_Road_Part_ID',
#        'Rpt_Block_Num', 'Rpt_Street_Name', 'Private_Dr_Fl', 'Toll_Road_Fl',
#        'Crash_Speed_Limit', 'Road_Constr_Zone_Fl', 'Road_Constr_Zone_Wrkr_Fl',
#        'At_Intrsct_Fl', 'Rpt_Sec_Rdwy_Sys_ID', 'Rpt_Sec_Road_Part_ID',
#        'Rpt_Sec_Street_Name', 'Wthr_Cond_ID', 'Light_Cond_ID', 'Entr_Road_ID',
#        'Road_Algn_ID', 'Surf_Cond_ID', 'Traffic_Cntl_ID',
#        'Investigat_Notify_Time', 'Investigat_Notify_Meth',
#        'Investigat_Arrv_Time', 'Report_Date', 'Investigat_Comp_Fl',
#        'Investigator_Name', 'ID_Number', 'ORI_Number', 'Investigat_Agency_ID',
#        'Bridge_Detail_ID', 'Harm_Evnt_ID', 'Intrsct_Relat_ID', 'FHE_Collsn_ID',
#        'Obj_Struck_ID', 'Othr_Factr_ID', 'Road_Part_Adj_ID', 'Road_Cls_ID',
#        'Road_Relat_ID', 'Phys_Featr_1_ID', 'Phys_Featr_2_ID', 'Cnty_ID',
#        'City_ID', 'Latitude', 'Longitude', 'Street_Name', 'Txdot_Rptable_Fl',
#        'Onsys_Fl', 'Rural_Fl', 'Crash_Sev_ID', 'Pop_Group_ID', 'Located_Fl',
#        'Day_of_Week', 'Sus_Serious_Injry_Cnt', 'Nonincap_Injry_Cnt',
#        'Poss_Injry_Cnt', 'Non_Injry_Cnt', 'Unkn_Injry_Cnt', 'Tot_Injry_Cnt',
#        'Death_Cnt', 'Investigat_Service_ID'],
#       dtype='object')

# %%
keepsc=['Crash_ID', 'Crash_Date', 'Crash_Time','Day_of_Week', 
       'Rpt_Rdwy_Sys_ID', 'Rpt_Road_Part_ID', 'Toll_Road_Fl', 'Crash_Speed_Limit',
       'Road_Constr_Zone_Fl', 'Road_Constr_Zone_Wrkr_Fl', 'At_Intrsct_Fl',
       'Wthr_Cond_ID', 'Light_Cond_ID', 'Entr_Road_ID',
       'Road_Algn_ID', 'Surf_Cond_ID', 'Traffic_Cntl_ID','Latitude', 'Longitude'
       ]

# %%
df_crash=df_crash[keepsc].copy()
df_crash.head()
# Out:
#    Crash_ID  Crash_Date Crash_Time Day_of_Week  Rpt_Rdwy_Sys_ID  \
# 0  15657177  06/02/2019   12:58 PM         SUN               15
# 1  16473665  06/15/2019   11:00 AM         SAT                2
# 2  16871051  06/12/2019   09:53 AM         WED                2
# 3  17055798  06/04/2019   03:07 PM         TUE               19
# 4  17099571  06/01/2019   01:00 AM         SAT               19
#
#    Rpt_Road_Part_ID Toll_Road_Fl  Crash_Speed_Limit Road_Constr_Zone_Fl  \
# 0                 1            N                 40                   N
# 1                 1            N                 35                   N
# 2                 1            N                 45                   N
# 3                 1            N                 35                   N
# 4                 1            N                 30                   N
#
#   Road_Constr_Zone_Wrkr_Fl At_Intrsct_Fl  Wthr_Cond_ID  Light_Cond_ID  \
# 0                        N             N            11              4
# 1                        N             Y            11              1
# 2                        N             N            11              1
# 3                        N             N            12              1
# 4                        N             N            11              3
#
#    Entr_Road_ID  Road_Algn_ID  Surf_Cond_ID  Traffic_Cntl_ID   Latitude  \
# 0             0             4             1                1  32.280231
# 1             4             3             1                5  30.660685
# 2             0             1             1               20  33.203920
# 3             2             2             1               10  29.792394
# 4             0             1             1               11  32.797549
#
#    Longitude
# 0 -97.746616
# 1 -93.893906
# 2 -96.596654
# 3 -95.746539
# 4 -96.699878

# %%
df_final=df_final.merge(df_crash,left_on='Crash_ID', right_on='Crash_ID')
df_final.tail()
# Out:
#         Crash_ID  Unit_Nbr  Prsn_Nbr  Prsn_Type_ID  Prsn_Occpnt_Pos_ID  \
# 597978  17460970         1         1             1                   1
# 597979  17461030         1         1             1                   1
# 597980  17461030         2         1             1                   1
# 597981  17461292         1         1             1                   1
# 597982  17461292         2         1             1                   1
#
#         Prsn_Injry_Sev_ID  Prsn_Age  Prsn_Ethnicity_ID  Prsn_Gndr_ID  \
# 597978                  5      68.0                1.0             1
# 597979                  5      44.0                1.0             1
# 597980                  3      57.0                3.0             2
# 597981                  5      16.0                1.0             2
# 597982                  5      16.0                1.0             1
#
#         Prsn_Ejct_ID  ...  Road_Constr_Zone_Wrkr_Fl  At_Intrsct_Fl  \
# 597978             1  ...                         N              N
# 597979             1  ...                         N              N
# 597980             1  ...                         N              N
# 597981             1  ...                         N              Y
# 597982             1  ...                         N              Y
#
#         Wthr_Cond_ID  Light_Cond_ID Entr_Road_ID Road_Algn_ID Surf_Cond_ID  \
# 597978            11              6            0            1            0
# 597979            11              1           98            1            1
# 597980            11              1           98            1            1
# 597981            11              1            0            1            1
# 597982            11              1            0            1            1
#
#         Traffic_Cntl_ID   Latitude  Longitude
# 597978                1  28.954878 -97.987513
# 597979                8  32.756880 -94.354907
# 597980                8  32.756880 -94.354907
# 597981                8  31.279209 -94.579816
# 597982                8  31.279209 -94.579816
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Unit data

# %%
df_unit.shape
# Out:
# (654542, 100)

# %%
# Percentage of missing values for each feature
mvr=df_unit.isna().sum()/len(df_unit.Crash_ID)
valid_feat=mvr[mvr<0.01].index
print(len(valid_feat))
valid_feat
# Out:
# 12
# Index(['Crash_ID', 'Unit_Nbr', 'Unit_Desc_ID', 'Veh_Trvl_Dir_ID',
#        'First_Harm_Evt_Inv_ID', 'Sus_Serious_Injry_Cnt', 'Nonincap_Injry_Cnt',
#        'Poss_Injry_Cnt', 'Non_Injry_Cnt', 'Unkn_Injry_Cnt', 'Tot_Injry_Cnt',
#        'Death_Cnt'],
#       dtype='object')

# %%
keepsu=['Crash_ID', 'Unit_Nbr', 'Unit_Desc_ID']

# %%
df_unit=df_unit[keepsu].copy()
df_unit.head()
# Out:
#    Crash_ID  Unit_Nbr  Unit_Desc_ID
# 0  15657177         1             1
# 1  16473665         1             1
# 2  16473665         2             1
# 3  16871051         1             1
# 4  16871051         2             6

# %%
df_final=df_final.merge(df_unit,left_on=['Crash_ID', 'Unit_Nbr'], right_on=['Crash_ID', 'Unit_Nbr'])
print(df_final.shape)
df_final.tail()
# Out:
# (597983, 33)
#         Crash_ID  Unit_Nbr  Prsn_Nbr  Prsn_Type_ID  Prsn_Occpnt_Pos_ID  \
# 597978  17460970         1         1             1                   1
# 597979  17461030         1         1             1                   1
# 597980  17461030         2         1             1                   1
# 597981  17461292         1         1             1                   1
# 597982  17461292         2         1             1                   1
#
#         Prsn_Injry_Sev_ID  Prsn_Age  Prsn_Ethnicity_ID  Prsn_Gndr_ID  \
# 597978                  5      68.0                1.0             1
# 597979                  5      44.0                1.0             1
# 597980                  3      57.0                3.0             2
# 597981                  5      16.0                1.0             2
# 597982                  5      16.0                1.0             1
#
#         Prsn_Ejct_ID  ...  At_Intrsct_Fl  Wthr_Cond_ID  Light_Cond_ID  \
# 597978             1  ...              N            11              6
# 597979             1  ...              N            11              1
# 597980             1  ...              N            11              1
# 597981             1  ...              Y            11              1
# 597982             1  ...              Y            11              1
#
#         Entr_Road_ID Road_Algn_ID Surf_Cond_ID Traffic_Cntl_ID   Latitude  \
# 597978             0            1            0               1  28.954878
# 597979            98            1            1               8  32.756880
# 597980            98            1            1               8  32.756880
# 597981             0            1            1               8  31.279209
# 597982             0            1            1               8  31.279209
#
#         Longitude Unit_Desc_ID
# 597978 -97.987513            1
# 597979 -94.354907            1
# 597980 -94.354907            1
# 597981 -94.579816            1
# 597982 -94.579816            1
#
# [5 rows x 33 columns]

# %%
df_final.columns
# Out:
# Index(['Crash_ID', 'Unit_Nbr', 'Prsn_Nbr', 'Prsn_Type_ID',
#        'Prsn_Occpnt_Pos_ID', 'Prsn_Injry_Sev_ID', 'Prsn_Age',
#        'Prsn_Ethnicity_ID', 'Prsn_Gndr_ID', 'Prsn_Ejct_ID', 'Prsn_Rest_ID',
#        'Prsn_Airbag_ID', 'Prsn_Helmet_ID', 'Prsn_Drg_Rslt_ID', 'Crash_Date',
#        'Crash_Time', 'Day_of_Week', 'Rpt_Rdwy_Sys_ID', 'Rpt_Road_Part_ID',
#        'Toll_Road_Fl', 'Crash_Speed_Limit', 'Road_Constr_Zone_Fl',
#        'Road_Constr_Zone_Wrkr_Fl', 'At_Intrsct_Fl', 'Wthr_Cond_ID',
#        'Light_Cond_ID', 'Entr_Road_ID', 'Road_Algn_ID', 'Surf_Cond_ID',
#        'Traffic_Cntl_ID', 'Latitude', 'Longitude', 'Unit_Desc_ID'],
#       dtype='object')

# %%
df_final.dropna(inplace=True)

# %% [markdown]
# # Mapping the data

# %%
# Link between feature name and its coding sheet
link_c=pd.read_excel("Term.xlsx",sheet_name='Crash File Specification',header=6,usecols=['Column Header','Description','Data Values with Valid Years if Applicable'])
link_c.head()
